# %% [markdown]
# # SIMPLE CRICKET GAME

# %%
print("                                                         CRICKET GAME !")
print("                                                         --------------")
toss=["head","tails"]
bat=[1,2,4,6,0]
boll=[1,2,3,4,5,6,0]
total =0
for i in range(1):
    import random
    s = str(input("DO you want heads or tails ?"))
    t = random.choice(toss)
    if s == t:
        print("Its",t)
        print("You won the toss :")
        print("__________________")
        f = str(input("Do you want to chose bat or boll ? "))
        if f == "bat":
            while True :
                print("_________________________________________")
                g=str(input("Are you ready to play the  ball ? "))
                if g=="yes":
                    u=random.choice(bat)
                    p=["out","notout"]
                    r=random.choice(p)
                    if u==bat[4]:
                        print("\n")
                        print("_____________________________")
                        print("You are out :(")
                        print("You finishes on ",total,"runs")
                        print("_____________________________")
                        l=input("Do you want to take review : ? ")
                        if l=="yes":
                            print("The decision after reviewing is :",r)
                            if r==p[0]:
                                break
                            else:
                                print("______________________________________")
                                print("Ohh you are not out according to DRS :")
                                print("Lets start the batting again")
                                print("\n\n")
                                print("_________________________________________")
                                g=str(input("Are you ready to play the  ball ? "))
                                if g=="yes":
                                    u=random.choice(bat)
                                    if u==bat[4]:
                                        print("\n")
                                        print("_____________________________")
                                        print("You are out :(")
                                        print("You finishes on ",total,"runs")
                                        print("_____________________________")
                                        break
                                    elif u==1 or u==2:
                                        total+=u
                                        print("You score after this ball is ",total)
                                        print("___________________________________")
                                    elif u==4 or u==6 :
                                        print("You hit a boundry !")
                                        total+=u
                                        print("You score after this score is ",total,"runs")
                                        print("___________________________________________")
                        else:
                            break           
                    elif u==1 or u==2:
                        total+=u
                        print("You score after this ball is ",total)
                        print("___________________________________")
                    elif u==4 or u==6 :
                        print("You hit a boundry !")
                        total+=u
                        print("You score after this score is ",total,"runs")
                        print("___________________________________________")
            break
        run=0
        if f!="bat":
            while True:
                print("____________________________________")
                d=str(input("Are you ready for the balling ? " ))
                if d=="yes":
                    q=random.choice(boll)
                    if q==boll[6]:
                        print("________________________________________")
                        print("Congrats you have taken the wicket ! :) ")
                        break
                    else:
                        run+=q
                        print("After deploying ball you have been hit for a :",q)
                        print("The total score till now is : ",run)
                        print("__________________________________________________")
            break
    else:
        print("Its",t)
        print("You lost the toss !")
        print("Computer wanted you to bat first!")
        while True :
            print("_________________________________________")
            g=str(input("Are you ready to play the  ball ? "))
            if g=="yes":
                u=random.choice(bat)
                p=["out","notout"]
                r=random.choice(p)
                if u==bat[4]:
                    print("\n")
                    print("_____________________________")
                    print("You are out :(")
                    print("You finishes on ",total,"runs")
                    print("_____________________________")
                    print("_____________________________")
                    l=input("Do you want to take review : ? ")
                    if l=="yes":
                        print("The decision after reviewing is :",r)
                        if r==p[0]:
                            break
                        else:
                            print("______________________________________")
                            print("Ohh you are not out according to DRS :")
                            print("Lets start the batting again")
                            print("\n\n")
                            print("_________________________________________")
                            g=str(input("Are you ready to play the  ball ? "))
                            if g=="yes":
                                u=random.choice(bat)
                                if u==bat[4]:
                                    print("\n")
                                    print("_____________________________")
                                    print("You are out :(")
                                    print("You finishes on ",total,"runs")
                                    print("_____________________________")
                                    break
                                elif u==1 or u==2:
                                    total+=u
                                    print("You score after this ball is ",total)
                                    print("___________________________________")
                                elif u==4 or u==6 :
                                    print("You hit a boundry !")
                                    total+=u
                                    print("You score after this score is ",total,"runs")
                                    print("___________________________________________")
                            else:
                                break 
                    else:
                        break
                elif u==1 or u==2:
                    total+=u
                    print("You score after this ball is ",total)
                    print("___________________________________")
                elif u==4 or u==6 :
                    print("You hit a boundry !")
                    total+=u
                    print("You score after this score is ",total,"runs")
                    print("___________________________________________")
        break
# Out:
#                                                          CRICKET GAME !
#                                                          --------------
# DO you want heads or tails ?head
# Its head
# You won the toss :
# __________________
# Do you want to chose bat or boll ? bat
# _________________________________________
# Are you ready to play the  ball ? yes
# You score after this ball is  1
# ___________________________________
# _________________________________________
# Are you ready to play the  ball ? yes
#
#
# _____________________________
# You are out :(
# You finishes on  1 runs
# _____________________________
# Do you want to take review : ? yes
# The decision after reviewing is : notout
# ______________________________________
# Ohh you are not out according to DRS :
# Lets start the batting again
#
#
#
# _________________________________________
# Are you ready to play the  ball ? yes
# You hit a boundry !
# You score after this score is  5 runs
# ...
